# %% [markdown]
# 변수와 문자열을 배워보자

# %%
#주석 넣기 == 
# print : 출력 함수
print('안녕?')

# %% [markdown]
# ### 파이썬 기본 단축키

# %% [markdown]
# ![image.png](attachment:4e77dfea-044a-44b5-b386-491112170b69.png)

# %% [markdown]
# ![image.png](attachment:81a728a8-92fb-4fff-a621-f2e76ed94cda.png)

# %% [markdown]
# ### 간단한 변수 선언

# %% [markdown]
#  ![image.png](attachment:0b29e6d3-efff-462f-9a5f-3b961fb7b2b4.png)

# %%
# 간단한 변수 선언


num=3

# %%
print(num)
# Out:
# 3

# %%
#type : 변수의 타입
type(num)
# Out:
# int

# %%
float(num)
# Out:
# 3.0

# %%
num = 3.0

num
# Out:
# 3.0

# %%
type(num)
# Out:
# float

# %% [markdown]
# ### 변수명 규칙
# - 영문자, 숫자, 언더바 사용 가능
# - 숫자로 시작 불가능
# - 키워드 사용 불가능(if, and, True 등등)

# %% [markdown]
# ![image.png](attachment:c5a81c14-3e56-4452-82da-85373123db4d.png)

# %% [markdown]
# ![image.png](attachment:4ec1ff44-9f26-4307-93e8-d8c6d61b44e4.png)

# %% [markdown]
# 권장사항
# - 변수명의 첫글자는 항상 소문자
# - 두가지의 문자를 섞을 경우 두 단어를 구분
#      - number_list
#      - NumberList
#      - numberList

# %%
#파이썬 변수 선언 특징
d, e = 20, 30
e
# Out:
# 30

# %%
str1 = str2 = '파이썬'

str1
str2
# Out:
# '파이썬'

# %%
# print 내부 , 로 구분 가능

print(c,str2)
# Out:
# 김호성 파이썬

# %%
print(c+str2)
# Out:
# 김호성파이썬

# %%
# 키워드(예약어) 사용 불가능
if = 30
if
# Out:
#   Cell In[69], line 2
#     if = 30
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# print = 4
# 내장함수명을 사용하게 되면, 내장함수의 기능을 잃는다.

# %% [markdown]
# ### 내장함수 함정 예제

# %% [markdown]
# ![image.png](attachment:ff3a0170-7f92-4060-8d5c-8622ec9f1c9e.png)

# %% [markdown]
# ![image.png](attachment:b815c6e3-948a-4c0b-b64b-e0504624584c.png)

# %%
### sum << 내장함수
x = 100
y = 200
sum = x+y
print(sum)
# Out:
# 300

# %% [markdown]
# ### 이스케이프 코드
# 프로그래밍 할 때 사용할 수 있도록 미리 정의해둔 '문자 조합'

# %% [markdown]
# ![image.png](attachment:b39592e1-ff14-4cfb-af06-6d81d5419763.png)

# %% [markdown]
# ![image.png](attachment:44b54694-1252-48ed-b49e-5f793fc6a14d.png)

# %%
# she's gone

str3 = "she's gone"
print (str3)
# Out:
# she's gone

# %%
print('nnn\nnn')
# nnn이후 \n 개행 되어 nn만 출력
# Out:
# nnn
# nn

# %%
str4 = '''이렇게
여러줄을
입력이 가능하다'''
print(str4)
# Out:
# 이렇게
# 여러줄을
# 입력이 가능하다

# %%
'이렇게\n여러줄\n입력이 가능하다'
# Out:
# '이렇게\n여러줄\n입력이 가능하다'

# %%
print(a)
'''
문자열 부분은 실행되지 않으므로
파이썬에서는 주석처럼 사용이 가능하다
'''
print(b)
# Out:
# 10
# 15

# %% [markdown]
# ### 인덱싱 슬라이싱

# %% [markdown]
# ![image.png](attachment:7685c697-451e-426d-a813-97a85914a4a1.png)

# %% [markdown]
# ![image.png](attachment:b3403d32-eb6e-4a7a-b715-551b4832e31f.png)

# %% [markdown]
# ![image.png](attachment:37f49613-f6fb-4f34-8707-c0b1de1dc29a.png)

# %% [markdown]
# ![image.png](attachment:d77a1ba8-779e-4970-b255-c947f25f779d.png)

# %% [markdown]
# ![image.png](attachment:81013811-60cd-41d3-b045-38c085a8b15b.png)

# %% [markdown]
# ![image.png](attachment:03631e86-5e2e-4d6a-9d22-3afd1a1b9f78.png)

# %%
day = "2020년 3월 3일의 날씨는 맑음입니다."
날짜 = day[:11]
날씨 = day[-6:-4]

print(날짜)
print(날씨)
# Out:
# 2020년 3월 3일
# 맑음

# %% [markdown]
# ### 문자열 포매팅
# - 문자열 안의 특정한 값을 바꿔야 하는 경우

# %%
s1 = '오늘은 3월 25일 입니다.'

s1 = '오늘은 3월 26일 입니다'

print(s1)
# Out:
# 오늘은 3월 26일 입니다

# %%
# % 기호를 사용하는 방법

day = 22

# 정수형변수를 넣을 자리에 %d, 마지막에 %들어갈 변수명
s1 = '오늘은 3월 %d일입니다.'%day

# %d : 정수형
# %f : 실수형
# %s : 문자형

print(s1)
# Out:
# 오늘은 3월 22일입니다.

# %%
day += 1
# day = day + 1
print('오늘은 3월 %d일입니다.'%day)
# Out:
# 오늘은 3월 45일입니다.

# %%
# format 함수를 사용한 포매팅

month = 3
day = '이십오'

# .format(첫번째변수, 두번째변수,...)
# 자료형이 달라져도 상관없다.
s = '오늘은 {}월 {}일 입니다.'.format(month,day)

print(s)
# Out:
# 오늘은 3월 이십오일 입니다.

# %%
# f문자열을 사용한 포매팅
# 현재 가장 많이 쓰이는 방법. python3 부터 제공하는 기능

month = 4
day = 5

s = f'오늘은 {month}월 {day}일 입니다.'

print(s)
# Out:
# 오늘은 4월 5일 입니다.

# %%
a = 10
b = 15
c = '김호성'

print(a)
print(b)
print(c)
# Out:
# 10
# 15
# 김호성
